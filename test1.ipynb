# %%
import numpy as np
a=np.array([1,2,3])
b=np.arange(1,7)
print(b[0])
print(b[5])
b.shape
# Out:
# 1
# 6
# (6,)

# %%
c=np.array([[1,2,3],[4,5,6]])
print(c[1,2])
print(c[0,:])
# Out:
# 6
# [1 2 3]

# %%
d=np.arange(1,11)
d[2:7]
# Out:
# array([3, 4, 5, 6, 7])

# %%
#broadcast
print(a)
print(c)
add=a+c
print(add)
# Out:
# [1 2 3]
# [[1 2 3]
#  [4 5 6]]
# [[2 4 6]
#  [5 7 9]]

# %%
#unique value
np.unique(c)
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
#vectorization
c2=(c*5)
c2
# Out:
# array([[ 5, 10, 15],
#        [20, 25, 30]])

# %%
import pandas as pd
d=pd.DataFrame({"Name":["AAA","BBB","CCC","DDD"],"Mark":[19,82,99,10],"Grade":["C","B","A","D"]})
d
# Out:
#   Name  Mark Grade
# 0  AAA    19     C
# 1  BBB    82     B
# 2  CCC    99     A
# 3  DDD    10     D

# %%
#greater than 50 mark
d["Mark"]>50
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# Name: Mark, dtype: bool

# %%
#avg
d["Mark"].mean()
# Out:
# np.float64(52.5)

# %%
#rename
d['Mark'].rename("mark")
# Out:
# 0    19
# 1    82
# 2    99
# 3    10
# Name: mark, dtype: int64

# %%
#line chart
import matplotlib.pyplot as plt
x=[10,20,30,40,50]
y=[150,250,350,450,500]
plt.plot(x,y)
plt.show()

# %%
#bar chart
y=[150,250,350,450,500]
x=["mango","apple","grapes","banana","orange"]
plt.bar(x,y)
plt.show()

# %%
#mean
avg=np.array([50,55,24,90,82,15,23,75,64,23])
print(avg.mean())
# Out:
# 50.1

# %%
#median
mark=[50,55,24,90,82,15,23,75,64,23]
np.median(mark)
# Out:
# np.float64(52.5)

# %%
#mode
from scipy import stats
m=stats.mode(mark)
m
# Out:
# ModeResult(mode=np.int64(23), count=np.int64(2))

# %%
#standard deviations
sd=np.std(mark)
sd
# Out:
# np.float64(26.132164089489414)

# %%
#variance
v=(sd)**2
# Out:
# np.float64(682.8900000000001)
