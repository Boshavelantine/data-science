# %%
import pandas as pd
d=pd.read_csv("advertising.csv")
d
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
#column names
d.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
#checking  null  value in dataset
d.columns[d.isnull().any()]
# Out:
# Index([], dtype='object')

# %%
#datatype
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
#correlation
d.corr()
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.901208
# Radio      0.054809  1.000000   0.354104  0.349631
# Newspaper  0.056648  0.354104   1.000000  0.157960
# Sales      0.901208  0.349631   0.157960  1.000000

# %%
x=d[["TV","Radio"]]
y=d["Sales"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.6,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
#training 
lr=LinearRegression()
lr.fit(x,y)
# Out:
# LinearRegression()

# %%
#testing
pr=lr.predict(x_test)
pr
# Out:
# array([16.90911121, 20.38243344, 23.61202043,  9.22267399, 21.87753951,
#        12.47110641, 21.14037783,  8.59655253, 17.10472187, 16.57632034,
#         8.98251618,  8.30180611, 17.7635543 ,  8.12942354, 12.45157609,
#        14.73405424,  8.03996233, 17.88716162, 10.90653001, 20.50436345,
#        20.58865461, 12.24510831, 11.0190752 , 22.20399557,  9.38458127,
#         7.75824801, 20.86423915, 13.76965098, 10.64348878,  8.00339907,
#        15.7884357 , 10.59582626, 20.75520158, 10.23459567, 21.40442928,
#        21.27670971, 12.29796912, 22.63090513, 12.58776386,  6.2997052 ,
#        11.77220311, 15.26506903,  9.83919073,  9.37344932, 17.08466564,
#         7.10737568, 10.18976923, 15.21268363, 10.93713581, 11.73263588,
#        13.90455813, 14.56102391, 10.34542196,  9.22467218,  8.87651972,
#        12.28747004, 10.44940089, 24.93822776,  7.85228798, 15.7651051 ,
#        21.24676946, 16.9491583 , 12.64300467,  9.68859218, 20.89860809,
#         7.40198244, 23.58582996,  6.94588734, 12.46853029, 10.20458114,
#        11.12643101,  8.99768611, 16.82892341, 17.8479762 , 15.42985551,
#        18.2511778 , 15.55185089, 19.40345598, 17.20117899, 21.86382698])

# %%
#acurate % find
from sklearn.metrics import r2_score
r2_score(y_test,pr)
# Out:
# 0.9082599878976891

# %%
d.kurt()
# Out:
# TV          -1.226495
# Radio       -1.260401
# Newspaper    0.649502
# Sales       -0.640075
# dtype: float64

# %%
#visualization
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
fig=plt.figure()
ax=fig.add_subplot(111,projection="3d")
ax.scatter(x["TV"],x["Radio"],y)
